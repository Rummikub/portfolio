# %%
# !pip install pycaret
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
#from pycaret.regression import *
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_68020/3729869491.py in <module>
#       1 #from pycaret.regression import *
# ----> 2 import pandas as pd
#
# c:\Users\dotto\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#      41
#      42 if _missing_dependencies:  # pragma: no cover
# ---> 43     raise ImportError(
#      44         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      45     )
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
train_data = pd.read_pickle('train_dataset_v1.pkl')
train_data
train_data = train_data[np.isfinite(train_data).all(1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_68020/3895373021.py in <module>
# ----> 1 train_data = pd.read_pickle('train_dataset_v1.pkl')
#       2 train_data
#       3 print(train_data[pd.isinf(train_data)])
#
# NameError: name 'pd' is not defined

# %%
exp = setup(data = train_data, target = 'UHI Index', session_id=111)
best = compare_models()
tuned_best = tune_model(best[0], choose_better = True, early_stopping = True)
final_model = finalize_model(tuned_best)
saved_model = save_model(final_model, 'final_model_v2')
predict_model(final_model)

# %%
# predict on unseen data
loaded_model = load_model('final_model_v2')
unseen_predictions = predict_model(loaded_model, data=val_data)

submit_data['UHI Index'] = unseen_predictions['prediction_label']
